# %% [markdown]
# # Install Packages

# %%
# ! pip install python-dotenv
# ! pip -q install --upgrade langchain-openai python-docx PyPDF2 pypdf
# ! pip install chromadb langchain openai langchain-chroma chroma-migrate

# %%
import chromadb
print("ChromaDB SDK version:", chromadb.__version__)
# Out:
# ChromaDB SDK version: 0.5.23

# %% [markdown]
# # Load Secrets

# %%
import os
from dotenv import load_dotenv
from pathlib import Path

# Move up one directory to find .env
env_path = Path.cwd().parent / '.env'

# Load the .env file
load_dotenv(dotenv_path=env_path)

# Access your keys
groq_api_key = os.getenv('GROQ_API_KEY')
openai_api_key = os.getenv('OPENAI_API_KEY')

print(f"GROQ_API_KEY: {bool(groq_api_key)}")
print(f"OPENAI_API_KEY: {bool(openai_api_key)}")
# Out:
# GROQ_API_KEY: True
# OPENAI_API_KEY: True

# %% [markdown]
# # Initialize ChromaDB & LangChain

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
from langchain_chroma import Chroma

vector_store = Chroma(
    collection_name="example_collection",
    embedding_function=embeddings,
    persist_directory="./chroma_db",  # Where to save data locally, remove if not necessary
)


print("✅ LangChain + Chroma vector store ready (persistent, local)!")
# Out:
# ✅ LangChain + Chroma vector store ready (persistent, local)!

# %% [markdown]
# # Load your files, split into chunks, and upsert into ChromaDB

# %%
import os
from langchain.document_loaders import PyPDFLoader, Docx2txtLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

DATA_DIR = "./data"

# 1. Load & tag raw docs
raw_docs = []
for fname in os.listdir(DATA_DIR):
    path = os.path.join(DATA_DIR, fname)
    if fname.lower().endswith(".pdf"):
        loader = PyPDFLoader(path)
    elif fname.lower().endswith(".docx"):
        loader = Docx2txtLoader(path)
    elif fname.lower().endswith(".txt"):
        loader = TextLoader(path, encoding="utf-8")
    else:
        continue

    docs = loader.load()
    # attach filename so we can delete/update later
    for d in docs:
        d.metadata["source"] = fname
    raw_docs.extend(docs)

print(f"Loaded {len(raw_docs)} document chunks from {len(os.listdir(DATA_DIR))} files.")

# 2. Split into manageable pieces
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
chunks = splitter.split_documents(raw_docs)
print(f"Split into {len(chunks)} total chunks.")
# Out:
# Loaded 53 document chunks from 2 files.
# Split into 179 total chunks.

# %%
print(chunks[0])
# Out:
# page_content='Addendum: Fitting the DESI BAO Data with Dark
# Energy Driven by the Cohen–Kaplan–Nelson Bound
# Patrick Adolf1∗, Martin Hirsch2†, Sara Krieg1‡, Heinrich P¨ as1§, Mustafa Tabet1¶
# 1Fakult¨ at f¨ ur Physik, Technische Universit¨ at Dortmund, D-44221 Dortmund, Germany
# 2Instituto de F` ısica Corpuscular (IFIC), Universidad de Valencia-CSIC,
# E-46980 Valencia, Spain
# April 23, 2025
# Abstract
# Motivated by the recent Year-2 data release of the DESI collaboration, we update our results on time-
# varying dark energy models driven by the Cohen–Kaplan–Nelson bound. The previously found preference of
# time-dependent dark energy models compared to ΛCDM is further strengthend by the new data release. For
# our particular models, we find that this preference increases up to ≈ 2.6 σ depending on the used supernova
# dataset.
# 1 Introduction
# In this addendum, we update the results of our previous work [1] in the light of the recent Year-2 data release' metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2025-04-23T00:02:31+00:00', 'author': '', 'keywords': '', 'moddate': '2025-04-23T00:02:31+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'astro_physics_1.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}

# %%
# For a single document
print(chunks[0].metadata['source'])

# # To print the file names of all documents
# for doc in chunks:
#     print(doc.metadata['source'])
# Out:
# astro_physics_1.pdf

# %% [markdown]
# # Insert Embeddings into ChromaDB

# %%
# 3. Upsert your document chunks
vector_store.add_documents(chunks)

# 4. Write everything immediately to disk
# vector_store.persist()

print(f"✔️ Ingested {len(chunks)} chunks into 'file_embeddings' collection.")
# Out:
# ✔️ Ingested 179 chunks into 'file_embeddings' collection.

# %% [markdown]
# # Filter and Query Using Filename

# %%
# # Replace with your actual filename
file_name = "CSE_1.pdf"

col = vector_store._collection

#  Use a metadata “where” filter to get only that file’s vectors
results = col.get(
    where={"source": file_name}
    # include=["metadatas"]    # <-- you can include metadatas/documents if you want, but not "ids"
)
vector_ids = results["ids"]

print(f"🔍 Found {len(vector_ids)} embeddings for '{file_name}':\n{vector_ids}")
# Out:
# 🔍 Found 978 embeddings for 'CSE_1.pdf':
# ['72c7c99c-2353-4cb0-b062-9d164da1811d', '85965409-3ee3-4e67-aa33-837b6987b3ca', '10b10807-24cb-4c24-adba-8043ece05a44', '4d9146e9-d15e-4f13-98ff-68c2d70e9fe4', 'da4cec38-1d39-48dd-a0b5-9c7794d8bff2', '3d1a1341-d95f-42a3-974e-4dfe5e89157d', '9fe62d75-36fa-4f37-b6f8-d93bf1717c4a', '34a38db5-e823-4dbc-aea9-00a7b316f2a5', 'cb40398f-5a0f-4a06-88fb-31d89ef3013a', 'd7626970-b48c-49f4-8f78-010bb9c79a57', 'dc2aac5e-bbf3-4d86-a343-5056327d3b98', '5e42eed3-9fef-490a-9b6c-ee3dc34273eb', '7349472c-13aa-4098-8dcd-10a62adc792f', '69633824-8d2a-4941-bb8f-b05c66585af9', 'a9ef68ea-213a-4e01-86ad-1776e3565d57', '310b471d-1481-454b-9beb-43200549e07d', 'b4d67271-386d-4ef2-8d33-6ebc02598b39', '132a34d0-80c5-41d1-a3f7-e7b5aab5dfd3', '483a14a0-4da7-46cc-8dad-7cb92b0136c9', 'a0feb1b1-496b-45af-93a2-124aafce6b0b', 'b4f2bb00-5554-409d-bfc8-08d3842f567e', '81d8b252-6642-4cc0-9bcf-a6f0fabd5854', '423406f6-d11c-4e56-ac88-0b561138cbcb', '464f7d80-146e-4a2c-8cb0-c33c98742f3b', 'f9b4505f-d935-4f8b-ad9b-156736ef7830', '7c4d4444-6c66-4420-8361-e957130e58cb', '4123694d-70f9-4a33-b9cd-b47b5c4c3fae', '90e70d63-26f3-47f2-b433-dac265fb4f5c', 'b70e257f-8c1b-4a6d-83eb-c48a1807e364', '998be722-d821-4491-80f4-8e95640d4af6', '66f252b0-b396-4ad4-8f22-2ce6a22cdbf4', 'b678447e-972c-4473-907f-2a9a67974c34', '7134fbe8-df77-4b9f-8808-f16b9d5c0b30', '4e9a7b23-71b7-45a5-b454-99501f222fe7', 'b1de4386-e3f6-431d-9ff4-8f4529191144', '814150b8-f753-48a2-b097-71914222209e', '4bd72674-52be-44fd-9a60-e4fe8eba92cd', 'e6a717af-3c70-481d-bcb7-c8e7061158cf', '2c5d9040-7979-447c-96ed-3851c8789fa2', 'e3f6bd4b-e342-4b8d-9af0-6ec2
# %% [markdown]
# # Create a Retriever (For RAG)

# %%
# Step 1: build your retriever (no extra imports needed)
retriever =  vector_store.as_retriever(
    search_type="mmr", search_kwargs={"k": 1, "fetch_k": 5}
)
print("Retriever initialized:", retriever)
# Out:
# Retriever initialized: tags=['Chroma', 'OpenAIEmbeddings'] vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x0000012AB0634B30> search_type='mmr' search_kwargs={'k': 1, 'fetch_k': 5}

# %% [markdown]
# # Create the RetrievalQA chain

# %%
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA

# 1. Instantiate an LLM
llm = ChatOpenAI(temperature=0)

# 2. Build the RetrievalQA chain
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=retriever,
    return_source_documents=True
)

print("✅ RetrievalQA chain is ready")
# Out:
# ✅ RetrievalQA chain is ready

# %% [markdown]
# # Test your RetrievalQA chain

# %%
# 1. Define your query
# query = "What are the main topics covered in CSE_1.pdf?"
query = "Tell me about Learning in Dynamic Bayesian Stackelberg Games"

# 2. Run the RetrievalQA chain
result =  qa_chain.invoke({"query": query})

# 3. Print the answer
print("📝 Answer:\n", result["result"])

# 4. Inspect source documents
print("\n🔍 Source chunks:")
for doc in result["source_documents"]:
    print(f"- {doc.metadata['source']} (chunk snippet: {doc.page_content[:150]}...)")
# Out:
# 📝 Answer:
#  In Learning in Dynamic Bayesian Stackelberg Games, the leader's focus is on maximizing their utility over the rounds of the game rather than identifying the follower's type, which is common in traditional learning paradigms. The leader plays a Dynamic Bayesian Stackelberg Policy (DSP) that specifies their strategy at each round, committing to this policy before the game starts. The follower observes this policy in advance. The optimal DSP is known as the Dynamic Bayesian Stackelberg Equilibrium (DSE). This approach is used in various fields such as dynamic pricing problems, dynamic mechanism design, and Stackelberg security games.
#
# 🔍 Source chunks:
# - CSE_1.pdf (chunk snippet: drawn from µ. We denote a specific dynamic Bayesian Stackelberg game as {R, Θ, {Cθ}θ∈Θ, µ, T}.
# The leader plays a Dynamic Bayesian Stackelberg Policy ...)

# %% [markdown]
# # Initiate Agno Agent

# %%
from agno.agent import Agent
from agno.tools.duckduckgo import DuckDuckGoTools
from agno.knowledge.langchain import LangChainKnowledgeBase
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA
from pydantic import BaseModel, Field
from typing import List

# %%
# Knowledge Base
knowledge_base = LangChainKnowledgeBase(retriever=retriever)

# %%
# Define Pydantic model for structured output
class AnswerOutput(BaseModel):
    query: str = Field(..., description="The user's original query.")
    answer: str = Field(..., description="The answer to the user's query.")
    type: str = Field(..., description="Source of the answer: 'Knowledge/RAG' or 'Web Search'.")
    sources: List[str] = Field(..., description="List of sources used (URLs or document names).")

# %%
# Agent with structured_output using Pydantic model
agent = Agent(
    tools=[DuckDuckGoTools()],
    knowledge=knowledge_base,
    instructions=[
        "Try to answer the query using the knowledge base (RAG) first.",
        "If the knowledge base does not contain the information or the user asks for a web search, use DuckDuckGo.",
        "Return your response following the provided structured format."
    ],
    response_model=AnswerOutput,  # <-- Pydantic model here
    show_tool_calls=True,
    markdown=False,
)

# %% [markdown]
# # Test the agent

# %%
from agno.agent import RunResponse
from rich.pretty import pprint
from datetime import datetime

start_time = datetime.now()
print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

# Test the agent
# response: RunResponse = agent.run("What are the latest developments in AI, and how do they relate to the concepts in our knowledge base?")
response: RunResponse = agent.run("Tell me about Learning in Dynamic Bayesian Stackelberg Games")

end_time = datetime.now()
elapsed = end_time - start_time

print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Elapsed Time: {elapsed.total_seconds():.2f} seconds")  # <-- FIXED
# Out:
# Start Time: 2025-06-08 15:15:10
# End Time: 2025-06-08 15:15:18
# Elapsed Time: 8.41 seconds

# %%
# Pretty print the structured content (your AnswerOutput model)
pprint(response.content)
# Out:
# AnswerOutput(
# │   query='Learning in Dynamic Bayesian Stackelberg Games',
# │   answer="In Dynamic Bayesian Stackelberg Games, the focus is on how the leader can optimize their utility over multiple rounds of the game rather than merely identifying the follower's type. The leader employs a Dynamic Bayesian Stackelberg Policy (DSP), which specifies the strategy at each round based on the follower's past responses. This policy outlines a leader strategy for each round and is committed to before the game begins, allowing the follower to observe it in advance. The optimal DSP results in what's called the Dynamic Bayesian Stackelberg Equilibrium (DSE). The leader's strategy in these games is about learning and adapting to the responses of the follower to maximize the leader's utility, rather than directly learning the type of the follower as in traditional learning scenarios.",
# │   type='Knowledge/RAG',
# │   sources=['CSE_1.pdf']
# )

# %%
# Or access individual fields
print(f"Query: {response.content.query}")
print(f"Answer: {response.content.answer}")
print(f"Type: {response.content.type}")
print(f"Sources: {response.content.sources}")
# Out:
# Query: Learning in Dynamic Bayesian Stackelberg Games
# Answer: In Dynamic Bayesian Stackelberg Games, the focus is on how the leader can optimize their utility over multiple rounds of the game rather than merely identifying the follower's type. The leader employs a Dynamic Bayesian Stackelberg Policy (DSP), which specifies the strategy at each round based on the follower's past responses. This policy outlines a leader strategy for each round and is committed to before the game begins, allowing the follower to observe it in advance. The optimal DSP results in what's called the Dynamic Bayesian Stackelberg Equilibrium (DSE). The leader's strategy in these games is about learning and adapting to the responses of the follower to maximize the leader's utility, rather than directly learning the type of the follower as in traditional learning scenarios.
# Type: Knowledge/RAG
# Sources: ['CSE_1.pdf']

# %% [markdown]
# # Multi-Lingual Agent

# %%
# Agent with structured_output using Pydantic model
agent = Agent(
    tools=[DuckDuckGoTools()],
    knowledge=knowledge_base,
    instructions=[
        "Understand user's query and translate into English to use the knowledge-base and web search"
        "Try to answer the query using the knowledge base (RAG) first.",
        "If the knowledge base does not contain the information or the user asks for a web search, use DuckDuckGo.",
        "Return your response following the provided structured format."
        "Answer in the same language as of user's query"
    ],
    response_model=AnswerOutput,  # <-- Pydantic model here
    show_tool_calls=True,
    markdown=False,
)

# %%
from agno.agent import RunResponse
from rich.pretty import pprint
from datetime import datetime

start_time = datetime.now()
print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

# Test the agent
# response: RunResponse = agent.run("What are the latest developments in AI, and how do they relate to the concepts in our knowledge base?")
response: RunResponse = agent.run("ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখা সম্পর্কে আমাকে বলুন")

end_time = datetime.now()
elapsed = end_time - start_time

print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Elapsed Time: {elapsed.total_seconds():.2f} seconds")  # <-- FIXED
# Out:
# Start Time: 2025-06-08 15:15:18
# End Time: 2025-06-08 15:15:29
# Elapsed Time: 10.14 seconds

# %%
# Pretty print the structured content (your AnswerOutput model)
pprint(response.content)
# Out:
# AnswerOutput(
# │   query='ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখা সম্পর্কে আমাকে বলুন',
# │   answer='ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমগুলিতে শেখা হলো একটি প্রক্রিয়া যেখানে এক বা একাধিক নেতা (লিডার) এবং অনুসারী (ফলোয়ার) তাদের নীতিগুলিকে উন্নত করতে শেখে। এই ধরনের গেমগুলিতে শেখা শুধুমাত্র যোগাযোগের বিকল্প নয় বরং এর মাধ্যমে একটি কার্যকর ডায়নামিক নীতি নিরূপণ করা সম্ভব। যখন সময় পরিসীমা (T) ১ হয় তখন ডায়নামিক স্ট্যাকেলবার্গ সমীকরণ (DSE) বেয়েসিয়ান স্ট্যাকেলবার্গ সমীকরণে (BSE) রুপান্তরিত হয়, যা NP-কঠিন সমস্যা হিসেবে পরিচিত। T বেশি হলে, ডায়নামিক নীতি সম্পূর্ণ করতে স্থান \x00 nT \x01 লাগতে পারে এবং এই সমস্যা সমাধানে সময় লাগে T এবং |Θ| এর উপর নির্ভরশীল। সমস্যার সমাধানে কার্যকর পদ্ধতি হিসেবে একটি মিশ্র সংখ্যা লিনিয়ার প্রোগ্রাম (MILP) প্রণয়ন করা হয়েছে, যা সময়ের সাথে T এবং |Θ| এর উপর নির্ভর করে কাজ করে।',
# │   type='Knowledge/RAG',
# │   sources=['CSE_1.pdf']
# )

# %% [markdown]
# # Light RAG

# %%
# !pip install -q lightrag-hku
# !pip install -q pdfplumber
# !pip install nest_asyncio
# !pip install -q nest_asyncio

# %%
# Ensure your OpenAI key is set
import os
os.environ["OPENAI_API_KEY"] = openai_api_key

import nest_asyncio
nest_asyncio.apply()                                  

from pathlib import Path
from lightrag import LightRAG, QueryParam             # :contentReference[oaicite:0]{index=0}
from lightrag.llm.openai import gpt_4o_mini_complete, openai_embed
from lightrag.kg.shared_storage import initialize_pipeline_status
from lightrag.utils import setup_logger

setup_logger("lightrag", level="INFO")
# Out:
# 2025-06-08 15:15:29 - pipmaster.package_manager - INFO - Targeting pip associated with Python: C:\Users\lenovo\anaconda3\python.exe | Command base: C:\Users\lenovo\anaconda3\python.exe -m pip

# %%
import shutil, os
WORKING_DIR = "./light_rag_storage"
if os.path.exists(WORKING_DIR):
    shutil.rmtree(WORKING_DIR)
os.makedirs(WORKING_DIR)

rag = LightRAG(
    working_dir=WORKING_DIR,
    embedding_func=openai_embed,
    llm_model_func=gpt_4o_mini_complete,
)
# Out:
# INFO: Process 3612 Shared-Data created for Single Process
# INFO: Created new empty graph
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': './light_rag_storage\\vdb_entities.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': './light_rag_storage\\vdb_relationships.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 1536, 'metric': 'cosine', 'storage_file': './light_rag_storage\\vdb_chunks.json'} 0 data

# %%
await rag.initialize_storages()
await initialize_pipeline_status()
# Out:
# INFO: Process 3612 initialized updated flags for namespace: [full_docs]
# INFO: Process 3612 ready to initialize storage namespace: [full_docs]
# INFO: Process 3612 KV load full_docs with 0 records
# INFO: Process 3612 initialized updated flags for namespace: [text_chunks]
# INFO: Process 3612 ready to initialize storage namespace: [text_chunks]
# INFO: Process 3612 KV load text_chunks with 0 records
# INFO: Process 3612 initialized updated flags for namespace: [entities]
# INFO: Process 3612 initialized updated flags for namespace: [relationships]
# INFO: Process 3612 initialized updated flags for namespace: [chunks]
# INFO: Process 3612 initialized updated flags for namespace: [chunk_entity_relation]
# INFO: Process 3612 initialized updated flags for namespace: [llm_response_cache]
# INFO: Process 3612 ready to initialize storage namespace: [llm_response_cache]
# INFO: Process 3612 KV load llm_response_cache with 0 records
# INFO: Process 3612 initialized updated flags for namespace: [doc_status]
# INFO: Process 3612 ready to initialize storage namespace: [doc_status]
# INFO: Process 3612 doc status load doc_status with 0 records
# INFO: Process 3612 storage namespace already initialized: [full_docs]
# INFO: Process 3612 storage namespace already initialized: [text_chunks]
# INFO: Process 3612 storage namespace already initialized: [llm_response_cache]
# INFO: Process 3612 storage namespace already initialized: [doc_status]
# INFO: Process 3612 Pipeline namespace initialized
# INFO: Storage Initialization completed!

# %%
from pathlib import Path                                  # need Path import
from langchain.document_loaders import PyPDFLoader, Docx2txtLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# 1) Locate all source files
DATA_DIR = Path("./data")
raw_docs = []

for file_path in DATA_DIR.iterdir():
    suffix = file_path.suffix.lower()
    if suffix == ".pdf":
        loader = PyPDFLoader(str(file_path))
    elif suffix == ".docx":
        loader = Docx2txtLoader(str(file_path))
    elif suffix == ".txt":
        loader = TextLoader(str(file_path), encoding="utf-8")
    else:
        continue

    docs = loader.load()                                  # :contentReference[oaicite:0]{index=0}
    for doc in docs:
        doc.metadata["source"] = file_path.name           # track origin for citations
    raw_docs.extend(docs)

# 2) Split into ~1 000-token chunks
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
chunks   = splitter.split_documents(raw_docs)            # :contentReference[oaicite:1]{index=1}

# 3) Prepare for ingestion
texts      = [chunk.page_content       for chunk in chunks]
file_paths = [chunk.metadata["source"] for chunk in chunks]

print(f"Prepared {len(chunks)} chunks from {len(raw_docs)} documents")
print(file_paths)                                        # verify your sources
# Out:
# Prepared 179 chunks from 53 documents
# ['astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'astro_physics_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf', 'CSE_1.pdf']

# %%
# Build unique chunk IDs to bypass dedupe
chunk_ids = [f"{src}_{i}" for i, src in enumerate(file_paths)]

# Synchronous (blocking) insert:
await rag.ainsert(
    texts,
    ids=chunk_ids,
    file_paths=file_paths,
    split_by_character_only=True
)
# Out:
# INFO: Stored 179 new unique documents
# INFO: Processing 179 document(s)
# INFO: Extracting stage 1/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_96
# INFO: Extracting stage 2/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_85
# INFO: limit_async: 16 new workers initialized
# INFO: limit_async: 4 new workers initialized
# INFO:  == LLM cache == saving default: 61f2011035702e91f33baae2b4311957
# INFO:  == LLM cache == saving default: 80d4739eeca13f58f9d5fd52f5dff2ab
# INFO: Chunk 1 of 1 extracted 3 Ent + 2 Rel
# INFO: Merging stage 2/179: CSE_1.pdf
# INFO: Updating 3 entities  2/179: CSE_1.pdf
# INFO: Extracting stage 3/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_45
# INFO:  == LLM cache == saving default: ecfd80d73af58540115b54a3720e0727
# INFO: Updating 2 relations 2/179: CSE_1.pdf
# INFO: Writing graph with 3 nodes, 2 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 2/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 03dc6904cf098f7c30f2bcfb513af419
# INFO:  == LLM cache == saving default: 9f256cd6e7657267cdb6da23f7387d77
# INFO: Chunk 1 of 1 extracted 6 Ent + 4 Rel
# INFO: Merging stage 1/179: CSE_1.pdf
# INFO: Updating 6 entities  1/179: CSE_1.pdf
# INFO: Extracting stage 4/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_103
# INFO: Updating 4 relations 1/179: CSE_1.pdf
# INFO: Writing graph with 9 nodes, 6 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 1/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: e06292f77a516de64b1a2c4444cac359
# INFO: Chunk 1 of 1 extracted 10 Ent + 8 Rel
# INFO: Merging stage 3/179: CSE_1.pdf
# INFO: Merge N: DSE | 1+1
# INFO: Updating 10 entities  3/179: CSE_1.pdf
# INFO: Extracting stage 5/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_46
# INFO:  == LLM cache == saving default: 0dcfd3833121b17adf43b7fa4643bb98
# INFO: Updating 8 relations 3/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: d553626c04c95189e7f0b47e46fe2a92
# INFO: Writing graph with 18 nodes, 14 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 3/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 32bbbb0484696602ffa4020fdf65c346
# INFO: Chunk 1 of 1 extracted 8 Ent + 7 Rel
# INFO: Merging stage 5/179: CSE_1.pdf
# INFO: Merge N: DSE | 1+2
# INFO: Merge N: Leader | 1+1
# INFO: Merge N: Follower | 1+1
# INFO: Merge N: Utility | 1+1
# INFO: Updating 8 entities  5/179: CSE_1.pdf
# INFO: Extracting stage 6/179: astro_physics_1.pdf
# INFO: Processing d-id: astro_physics_1.pdf_1
# INFO: Updating 7 relations 5/179: CSE_1.pdf
# INFO: Writing graph with 22 nodes, 21 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 5/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 519c958d00f05f543a994c7bdd59ff1e
# INFO:  == LLM cache == saving default: 1e464e5cb0af2781797d7ca3fe0d78a6
# INFO: Chunk 1 of 1 extracted 18 Ent + 9 Rel
# INFO: Merging stage 4/179: CSE_1.pdf
# INFO: Updating 18 entities  4/179: CSE_1.pdf
# INFO: Extracting stage 7/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_20
# INFO:  == LLM cache == saving default: 58c14c2b7941009ba0c8804172095646
# INFO: Updating 9 relations 4/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 26d0710eb363e3b1be16ef3d95454446
# INFO: Chunk 1 of 1 extracted 11 Ent + 12 Rel
# INFO: Extracting stage 8/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_38
# INFO: Merging stage 6/179: astro_physics_1.pdf
# INFO: Updating 11 entities  6/179: astro_physics_1.pdf
# INFO: Writing graph with 51 nodes, 42 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 4/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 6508bf1a35be85260304a5dec5031976
# INFO:  == LLM cache == saving default: e9840a0c8abcc4956aafff62e8dff42d
# INFO: Chunk 1 of 1 extracted 10 Ent + 8 Rel
# INFO: Extracting stage 9/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_150
# INFO: Updating 12 relations 6/179: astro_physics_1.pdf
# INFO:  == LLM cache == saving default: 78496c8e8c8edc3c6bba3a7c6a321d2d
# INFO:  == LLM cache == saving default: 97a3e358175c10115ac8068e59f2b777
# INFO: Chunk 1 of 1 extracted 6 Ent + 4 Rel
# INFO: Extracting stage 10/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_48
# INFO: Merging stage 7/179: CSE_1.pdf
# INFO: Merge N: Leader | 1+2
# INFO: Merge N: Follower | 1+2
# INFO: Merge E: Follower - Leader | 1+1
# INFO: Updating 10 entities  7/179: CSE_1.pdf
# INFO: Writing graph with 59 nodes, 49 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 6/179: astro_physics_1.pdf
# INFO:  == LLM cache == saving default: 09626652669ff77cd3c6140f3382da0e
# INFO:  == LLM cache == saving default: 55e394a7f80548a9592a85fb8b7bc676
# INFO: Chunk 1 of 1 extracted 6 Ent + 3 Rel
# INFO: Extracting stage 11/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_58
# INFO: Updating 8 relations 7/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 06f35f3c89b08b08fd73ccf47b4e72df
# INFO: Merging stage 8/179: CSE_1.pdf
# INFO: Updating 6 entities  8/179: CSE_1.pdf
# INFO: Writing graph with 65 nodes, 53 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 7/179: CSE_1.pdf
# INFO: Updating 4 relations 8/179: CSE_1.pdf
# INFO: Merging stage 9/179: CSE_1.pdf
# INFO: Updating 6 entities  9/179: CSE_1.pdf
# INFO: Writing graph with 71 nodes, 56 edges
# INFO:  == LLM cache == saving default: d7c122dbc07a0f5f54f8739fa337dff0
# INFO: Chunk 1 of 1 extracted 11 Ent + 8 Rel
# INFO: In memory DB persist to disk
# INFO: Completed processing file 8/179: CSE_1.pdf
# INFO: Extracting stage 12/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_81
# INFO:  == LLM cache == saving default: 70d8a2af2912c920cbd15e1754e6cdc1
# INFO: Chunk 1 of 1 extracted 7 Ent + 7 Rel
# INFO: Extracting stage 13/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_128
# INFO:  == LLM cache == saving default: cbc5f50afb2bd16d0a140055138c2e98
# INFO: Updating 3 relations 9/179: CSE_1.pdf
# INFO: Merging stage 10/179: CSE_1.pdf
# INFO: Merge N: Leader Utility | 1+1
# INFO: Merge N: DSE | 1+3
# INFO: Updating 11 entities  10/179: CSE_1.pdf
# INFO: Writing graph with 80 nodes, 64 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 9/179: CSE_1.pdf
# INFO: Updating 8 relations 10/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 7f8f6e9f3ab284cd410afe50e5e03c99
# INFO: Chunk 1 of 1 extracted 3 Ent + 4 Rel
# INFO: Extracting stage 14/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_142
# INFO: Merging stage 11/179: CSE_1.pdf
# INFO: Updating 7 entities  11/179: CSE_1.pdf
# INFO: Writing graph with 87 nodes, 71 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 10/179: CSE_1.pdf
# INFO: Updating 7 relations 11/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 480fbe522c6143ea53d4617ca22a3025
# INFO: Merging stage 12/179: CSE_1.pdf
# INFO: Updating 3 entities  12/179: CSE_1.pdf
# INFO: Writing graph with 91 nodes, 75 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 11/179: CSE_1.pdf
# INFO: Updating 4 relations 12/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 35cf6122293a16fe83e84b7b73f16ddb
# INFO: Writing graph with 91 nodes, 75 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 12/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 20928113a9796a8c50989607241874a2
# INFO: Chunk 1 of 1 extracted 13 Ent + 10 Rel
# INFO: Merging stage 13/179: CSE_1.pdf
# INFO: Updating 13 entities  13/179: CSE_1.pdf
# INFO: Extracting stage 15/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_26
# INFO:  == LLM cache == saving default: 5882c8d63fdb29f6aad6d52f21aedff8
# INFO: Chunk 1 of 1 extracted 12 Ent + 8 Rel
# INFO: Extracting stage 16/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_144
# INFO: Updating 10 relations 13/179: CSE_1.pdf
# INFO: Merging stage 14/179: CSE_1.pdf
# INFO: Merge N: Follower Type | 1+1
# INFO: Updating 12 entities  14/179: CSE_1.pdf
# INFO: Writing graph with 115 nodes, 93 edges
# INFO:  == LLM cache == saving default: 62f6f1414819925fc7962509968378f6
# INFO: In memory DB persist to disk
# INFO: Completed processing file 13/179: CSE_1.pdf
# INFO:  == LLM cache == saving default:
179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 1bbe7a116a6c3216a6f7d923c0fa4601
# INFO: Chunk 1 of 1 extracted 3 Ent + 3 Rel
# INFO: Merging stage 28/179: CSE_1.pdf
# INFO: Updating 3 entities  28/179: CSE_1.pdf
# INFO: Extracting stage 29/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_90
# INFO: Updating 3 relations 28/179: CSE_1.pdf
# INFO: Writing graph with 231 nodes, 194 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 28/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 8fc086a0a55c53bac35aa72d0b683f6d
# INFO:  == LLM cache == saving default: b4e2a71ee92d9772bbb9a8cd0dded6fd
# INFO: Chunk 1 of 1 extracted 14 Ent + 9 Rel
# INFO: Merging stage 27/179: CSE_1.pdf
# INFO: Merge N: Principal | 1+1
# INFO: Merge E: Attacker - Defender | 2+0
# INFO: Updating 14 entities  27/179: CSE_1.pdf
# INFO: Extracting stage 30/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_147
# INFO: Updating 8 relations 27/179: CSE_1.pdf
# INFO: Writing graph with 244 nodes, 202 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 27/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 8a7223921036ed5f8a71ee1453492599
# INFO:  == LLM cache == saving default: eb66c2d5e1376037408998edb14e4202
# INFO: Chunk 1 of 1 extracted 11 Ent + 9 Rel
# INFO: Merging stage 29/179: CSE_1.pdf
# INFO: Merge N: DSE | 1+4
# INFO: Merge N: Theorem 5 | 1+1
# INFO: Merge N: MILP | 1+1
# INFO: Updating 11 entities  29/179: CSE_1.pdf
# INFO: Extracting stage 31/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_88
# INFO: Updating 9 relations 29/179: CSE_1.pdf
# INFO: Writing graph with 252 nodes, 211 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 29/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 6bd3d8a097ff9531b32db5986621f9ec
# INFO: Chunk 1 of 1 extracted 9 Ent + 7 Rel
# INFO: Merging stage 30/179: CSE_1.pdf
# INFO: Merge N: T | 1+1
# INFO: Updating 9 entities  30/179: CSE_1.pdf
# INFO: Extracting stage 32/179: astro_physics_1.pdf
# INFO: Processing d-id: astro_physics_1.pdf_7
# INFO:  == LLM cache == saving default: 0a47b7d1b8e09337f537437861c620e4
# INFO: Updating 7 relations 30/179: CSE_1.pdf
# INFO: Writing graph with 260 nodes, 218 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 30/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 5d53a63b8a8446381895dc293a5ad60c
# INFO: Chunk 1 of 1 extracted 11 Ent + 8 Rel
# INFO: Merging stage 31/179: CSE_1.pdf
# INFO: Merge N: MILP | 1+2
# INFO: Merge N: Program (2) | 1+1
# INFO: LLM merge N: Leader | 1+5
# INFO: Extracting stage 33/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_136
# INFO:  == LLM cache == saving default: 374d3da109b4e49778d41480ae2391ba
# INFO:  == LLM cache == saving default: 8c8edde6d818439c682f7c08308b98f2
# INFO:  == LLM cache == saving default: b88481360a2f96f00b348d17586540cc
# INFO: LLM merge N: Follower | 1+5
# INFO:  == LLM cache == saving default: dc33d038b74e867655d3b2fa5af1c6ef
# INFO: Updating 11 entities  31/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 2c96e5e8c94a3e7c1277047e401ced29
# INFO: Chunk 1 of 1 extracted 11 Ent + 9 Rel
# INFO: Updating 8 relations 31/179: CSE_1.pdf
# INFO: Extracting stage 34/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_161
# INFO:  == LLM cache == saving default: 407a45553130a6a3b327d232c3675465
# INFO: Merging stage 32/179: astro_physics_1.pdf
# INFO: Updating 11 entities  32/179: astro_physics_1.pdf
# INFO: Writing graph with 278 nodes, 235 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file
edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 41/179: CSE_1.pdf
# INFO: Updating 8 relations 43/179: CSE_1.pdf
# INFO: Writing graph with 364 nodes, 316 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 43/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 94e36aab3616e71e119d304e6f8db636
# INFO:  == LLM cache == saving default: 9e4abb071bc791037374053d1a4d38e6
# INFO: Chunk 1 of 1 extracted 13 Ent + 9 Rel
# INFO: Merging stage 44/179: CSE_1.pdf
# INFO: Merge N: Follower Type θ | 1+1
# INFO: Merge N: Leader Utility | 1+2
# INFO: Merge N: Utility Function | 1+1
# INFO: Updating 13 entities  44/179: CSE_1.pdf
# INFO: Extracting stage 46/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_145
# INFO: Updating 9 relations 44/179: CSE_1.pdf
# INFO: Writing graph with 374 nodes, 325 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 44/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 9a23782a888959b9fb639936221508b5
# INFO:  == LLM cache == saving default: 88b0f8e3f41a8262642cfe39023ecafd
# INFO: Chunk 1 of 1 extracted 9 Ent + 8 Rel
# INFO: Merging stage 45/179: CSE_1.pdf
# INFO: Merge N: Assumption 1 | 1+2
# INFO: Merge N: No Learning Theorem | 1+3
# INFO: Merge N: Bayesian Stackelberg Games | 1+3
# INFO: Merge N: Optimal Static Strategy | 1+1
# INFO: Merge N: Dynamic Pricing Game | 1+1
# INFO: Updating 9 entities  45/179: CSE_1.pdf
# INFO: Extracting stage 47/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_57
# INFO: Updating 8 relations 45/179: CSE_1.pdf
# INFO: Writing graph with 378 nodes, 333 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 45/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: bd5ca0153398e837eb71049b7f3801d9
# INFO:  == LLM cache == saving default: 8913ff63d4896fc8ac9b1c237e70beae
# INFO: Chunk 1 of 1 extracted 13 Ent + 12 Rel
# INFO: Merging stage 46/179: CSE_1.pdf
# INFO: Merge N: Dynamic Policy | 1+3
# INFO: Merge N: Follower | 1+1
# INFO: Merge N: Leader | 1+1
# INFO: Merge N: Type θ | 1+1
# INFO: Merge N: RME | 1+2
# INFO: Merge E: Follower - Leader | 1+4
# INFO: Merge E: Dynamic Policy - Follower | 1+1
# INFO: Merge E: Dynamic Policy - Leader | 1+2
# INFO: Updating 13 entities  46/179: CSE_1.pdf
# INFO: Extracting stage 48/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_91
# INFO:  == LLM cache == saving default: 7c26ccdd1fe080ed3cfd0b19137cb83a
# INFO:  == LLM cache == saving default: 6b96141e96b709c29047b35b894ac03f
# INFO: Chunk 1 of 1 extracted 11 Ent + 12 Rel
# INFO: Extracting stage 49/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_172
# INFO: Updating 12 relations 46/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 0313265026fa27e380e57837ba9fdadd
# INFO:  == LLM cache == saving default: 1ce715e7adca2eceef097437a18f0c39
# INFO: Chunk 1 of 1 extracted 7 Ent + 6 Rel
# INFO: Extracting stage 50/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_69
# INFO: Merging stage 47/179: CSE_1.pdf
# INFO: Merge N: Leader | 1+2
# INFO: Merge N: Stackelberg Game | 1+1
# INFO: Merge N: Dynamic Policy | 1+4
# INFO: Merge N: Utility | 1+3
# INFO: Merge E: Dynamic Policy - Leader | 1+3
# INFO: Merge E: Leader - Utility | 1+1
# INFO: Updating 11 entities  47/179: CSE_1.pdf
# INFO: Writing graph with 393 nodes, 352 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file
179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 980536fc28d4d319a23e864a03f9cf5b
# INFO: Merging stage 58/179: CSE_1.pdf
# INFO: Merge N: Advances in Neural Information Processing Systems | 1+2
# INFO: Merge N: Econometrica | 1+1
# INFO: Merge N: Alessandro Pavan | 1+1
# INFO: Merge N: Ilya Segal | 1+1
# INFO: Merge N: Juuso Toikka | 1+1
# INFO: Merge N: Dynamic Mechanism Design | 1+1
# INFO: LLM merge N: Bayesian Stackelberg Games | 1+5
# INFO: Writing graph with 490 nodes, 433 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 59/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: e0f83a4ad3bb2493330a5022aa9b70b4
# INFO: Merge E: Alessandro Pavan - Ilya Segal | 1+1
# INFO: Merge E: Ilya Segal - Juuso Toikka | 1+1
# INFO: Updating 19 entities  58/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: a174c2ed7339d9626ef28dd5f9f6a25f
# INFO:  == LLM cache == saving default: faa4f139a6acd85865339816f505a742
# INFO: Chunk 1 of 1 extracted 7 Ent + 4 Rel
# INFO: Extracting stage 62/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_67
# INFO:  == LLM cache == saving default: f5810456616cc56036a2762bbdec06c8
# INFO: Updating 10 relations 58/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 636358dd525e65c372b885cfa0ca00e9
# INFO: Chunk 1 of 1 extracted 14 Ent + 12 Rel
# INFO: Extracting stage 63/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_167
# INFO:  == LLM cache == saving default: f05f7ae5721cb534e4abbd952ac9f2bc
# INFO: Chunk 1 of 1 extracted 7 Ent + 6 Rel
# INFO: Extracting stage 64/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_63
# INFO: Merging stage 61/179: CSE_1.pdf
# INFO: Updating 7 entities  61/179: CSE_1.pdf
# INFO: Writing graph with 497 nodes, 445 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 58/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: ac73dcd9de3a7221994bddabdb1d98c2
# INFO: Updating 4 relations 61/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 0b4853e3129f417520a29489b75d4247
# INFO: Merging stage 60/179: astro_physics_1.pdf
# INFO: Merge N: CKN | 1+1
# INFO: Merge N: νCKN | 1+1
# INFO: Merge N: ΛCDM | 1+1
# INFO: Merge N: ωCDM | 1+1
# INFO: Merge N: ω0ωaCDM | 1+1
# INFO: Merge N: DESY5 | 1+2
# INFO: Merge N: Pantheon+ | 1+3
# INFO: Merge N: DESI BAO DR1 | 1+2
# INFO: Merge N: DR2 | 1+1
# INFO: Merge N: χ2 | 1+1
# INFO: Merge N: DESI | 1+1
# INFO: Merge E: CKN - χ2 | 1+1
# INFO: Merge E: νCKN - χ2 | 1+1
# INFO: Updating 14 entities  60/179: astro_physics_1.pdf
# INFO: Writing graph with 500 nodes, 455 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 61/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: f14f3f29774086cf5bc5b5c31234aff6
# INFO: Chunk 1 of 1 extracted 7 Ent + 6 Rel
# INFO: Extracting stage 65/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_146
# INFO: Updating 12 relations 60/179: astro_physics_1.pdf
# INFO: Merging stage 62/179: CSE_1.pdf
# INFO: Merge N: Hyperplanes | 1+1
# INFO: Merge N: Follower Type θ | 1+2
# INFO: Updating 7 entities  62/179: CSE_1.pdf
# INFO: Writing graph with 505 nodes, 461 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 60/179: astro_physics_1.pdf
# INFO:  == LLM cache == saving default: a0a26a7b1e7019c95c2a0d79c08d22b6
# INFO: Updating 6 relations 62/179: CSE_1.pdf
# INFO: Merging stage 63/179: CSE_1.pdf
# INFO: LLM merge N: MILP | 1+5
# INFO: Writing graph with 505 nodes, 461 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 62/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: c2aea0b3c2fab9fc2e0fbf4f3c01dc14
# INFO: Chunk 1 of 1 extracted 9 Ent + 8 Rel
# INFO: Extracting stage 66/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_140
# INFO:  == LLM cache == saving default: 04b536f0e348deab10efc08bbe38ac9c
# INFO: Merge N: MIP | 1+1
# INFO: Merge E: MILP - MIP | 1+1
# INFO: Updating 7 entities  63/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: bb9713166b9135594ba1519e8e453664
# INFO: Chunk 1 of 1 extracted 9 Ent + 9 Rel
# INFO: Extracting stage 67/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_98
# INFO:  == LLM cache == saving default: 854cec04917953df32f13e231aa63003
# INFO: Updating 6 relations 63/179: CSE_1.pdf
# INFO: Merging stage 64/179: CSE_1.pdf
# INFO: Merge N: Assumption 1 | 1+3
# INFO: Merge N: BSE Leader Strategy | 1+1
# INFO: Merge N: Theorem 2 | 1+1
# INFO: Merge N: Sub-group Θ′ | 1+1
# INFO: Updating 9 entities  64/179: CSE_1.pdf
# INFO: Writing graph with 515 nodes, 474 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 63/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: a547bd7962875c01b059289b894ab9c3
# INFO: Updating 8 relations 64/179: CSE_1.pdf
# INFO: Merging stage 65/179: CSE_1.pdf
# INFO: Merge N: Leader Strategies | 1+1
# INFO: Merge N: Follower Type | 1+2
# INFO: Merge N: Leader | 1+3
# INFO: Merge N: Follower | 1+2
# INFO: Merge N: Rounds | 1+1
# INFO: LLM merge E: Follower - Leader | 1+5
# INFO: Writing graph with 519 nodes, 477 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 64/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 78982caa4a9027162b5284853f52696c
# INFO: Chunk 1 of 1 extracted 12 Ent + 7 Rel
# INFO: Extracting stage 68/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_19
# INFO:  == LLM cache == saving default: 11b1671653568f29ba6220cbddef07c9
# INFO: Merge E: Leader - Rounds | 1+1
# INFO: Updating 9 entities  65/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 0f6ce723570ae3768430558ae91e39e0
# INFO: Chunk 1 of 1 extracted 13 Ent + 9 Rel
# INFO: Extracting stage 69/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_43
# INFO:  == LLM cache == saving default: 22d990c47a2ee908fb6d29e1c5163cac
# INFO:  == LLM cache == saving default: 9b215f590e92f8a705ef935be66855b9
# INFO: Updating 9 relations 65/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 5fbb8af79862386ad8f134335071221e
# INFO: Chunk 1 of 1 extracted 6 Ent + 5 Rel
# INFO: Extracting stage 70/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_84
# INFO: Merging stage 66/179: CSE_1.pdf
# INFO: LLM merge N: Θ | 1+5
# INFO: Writing graph with 524 nodes, 481 edges
# INFO:  == LLM cache == saving default: e5d2b088461fe1111d41ff4cd56ed04c
# INFO: Chunk 1 of 1 extracted 7 Ent + 5 Rel
# INFO: In memory DB persist to disk
# INFO: Completed processing file 65/179: CSE_1.pdf
# INFO: Extracting stage 71/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_139
# INFO:  == LLM cache == saving default: 2b7719ed987485dfc24c5cde01b15104
# INFO:  == LLM cache == saving default: 41ca2b15b27c753ed4b43589f98bfb36
# INFO:  == LLM cache == saving default: ddefa72d08d4d8023b11970706cdf844
# INFO: Merge N: n | 1+3
# INFO: Merge N: Assumption 2 | 1+4
# INFO: Merge N: Theorem 3 | 1+1
# INFO: Updating 12 entities  66/179: CSE_1.pdf
# INFO: Updating 7 relations 66/179: CSE_1.pdf
# INFO: Merging stage 67/179: CSE_1.pdf
# INFO: Merge N: UDSE | 1+1
# INFO: Merge N: DSE | 1+4
# INFO: Merge N: Average Leader Utility | 1+1
# INFO: Merge N: Utility | 1+4
# INFO: Merge N: Optimal Static Policy | 1+1
# INFO: Updating 13 entities  67/179: CSE_1.pdf
# INFO: Writing graph with 535 nodes, 497 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file
179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 4a66e0e3932bab2cc70898f2c1109809
# INFO: Chunk 1 of 1 extracted 10 Ent + 10 Rel
# INFO: Merging stage 73/179: CSE_1.pdf
# INFO: Merge N: Game of Chicken | 1+1
# INFO: Merge N: Defender | 1+1
# INFO: Merge N: Attacker | 1+1
# INFO: Merge E: Game of Chicken - Type C0 | 2+0
# INFO: Merge E: Game of Chicken - Type C1 | 2+0
# INFO: Updating 10 entities  73/179: CSE_1.pdf
# INFO: Extracting stage 75/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_31
# INFO:  == LLM cache == saving default: 648c3b41f387b3d06082ad692ed533ab
# INFO: Chunk 1 of 1 extracted 16 Ent + 7 Rel
# INFO: Extracting stage 76/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_66
# INFO:  == LLM cache == saving default: d64691423db6365208b414beb989ccf9
# INFO: Updating 8 relations 73/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: fbefeb8067ab6cbb0772302e9359f544
# INFO: Merging stage 74/179: CSE_1.pdf
# INFO: LLM merge N: Assumption 2 | 1+5
# INFO: Writing graph with 569 nodes, 535 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 73/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 2c6e695945b93ccc621fa615c6029fd0
# INFO: Chunk 1 of 1 extracted 5 Ent + 6 Rel
# INFO: Extracting stage 77/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_50
# INFO:  == LLM cache == saving default: e814c8d3e01fc0c777a6bb899f74da32
# INFO: Merge N: K | 1+1
# INFO: Merge N: Hθ | 1+1
# INFO: LLM merge N: m | 1+5
# INFO:  == LLM cache == saving default: f4d0edc5325f84c4f23ff82046a76732
# INFO: Chunk 1 of 1 extracted 8 Ent + 6 Rel
# INFO: Extracting stage 78/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_123
# INFO:  == LLM cache == saving default: 105dc06bd0a207136c4f0fec0137c901
# INFO: Merge N: Θ | 1+2
# INFO: Updating 16 entities  74/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: ea0f8dcb8f43cbca243fadb393ada073
# INFO:  == LLM cache == saving default: c39f46945ef2a76589458871d6329b19
# ...
# INFO: LLM merge N: Follower | 1+5
# INFO: Writing graph with 1056 nodes, 1157 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 158/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: f372bc8af794a64c4a52ce993c3779f6
# INFO:  == LLM cache == saving default: 0a09bf994120ff3653f12697a6df8097
# INFO: Merge N: Utility Matrix R | 1+1
# INFO: Merge E: Leader - Utility Matrix R | 1+1
# INFO: Updating 9 entities  159/179: CSE_1.pdf
# INFO: Updating 10 relations 159/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: c2760b4e01ff00106023732a094d1cea
# INFO: Chunk 1 of 1 extracted 9 Ent + 12 Rel
# INFO: Extracting stage 163/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_168
# INFO: Merging stage 160/179: CSE_1.pdf
# INFO: Merge N: Deng et al. | 1+1
# INFO: Merge N: Stackelberg Game | 1+2
# INFO: LLM merge N: No Learning Theorem | 1+5
# INFO: Writing graph with 1061 nodes, 1166 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 159/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: bbba6fb90f0410ffcc4e2100c246640d
# INFO: Chunk 1 of 1 extracted 8 Ent + 5 Rel
# INFO: Extracting stage 164/179: astro_physics_1.pdf
# INFO: Processing d-id: astro_physics_1.pdf_13
# INFO:  == LLM cache == saving default: 65e5c2ea051dbab2f5a099da1af63e62
# INFO: Merge N: Follower | 1+1
# INFO: Merge N: Leader | 1+3
# INFO: Merge E: Follower - Leader | 1+3
# INFO: Updating 7 entities  160/179: CSE_1.pdf
# INFO: Updating 8 relations 160/179: CSE_1.pdf
# INFO: Merging stage 161/179: astro_physics_1.pdf
# INFO: Merge N: ν | 1+1
# INFO: Merge N: Ω0 | 1+1
# INFO: Merge N: H0 | 1+3
# INFO: Merge N: rd | 1+1
# INFO: Merge N: Figure 4 | 1+1
# INFO: Merge E: H0 - Ω0 | 1+1
# INFO: Updating 9 entities  161/179: astro_physics_1.pdf
# INFO: Writing graph with 1067 nodes, 1184 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 160/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: e79393fcfe29d2e506860bc5ccf6ccf1
# INFO: Updating 12 relations 161/179: astro_physics_1.pdf
# INFO: Merging stage 162/179: CSE_1.pdf
# INFO: Merge N: Bayesian Stackelberg Game | 1+3
# INFO: Merge N: Utility Matrices | 1+2
# INFO: LLM merge N: DSE | 1+5
# INFO: Writing graph with 1067 nodes, 1184 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 161/179: astro_physics_1.pdf
# INFO:  == LLM cache == saving default: c0ff3feb6df78d38c10c230c8f124353
# INFO:  == LLM cache == saving default: 7d769fa4a69b81f64fb6fe58097f6f25
# INFO: Chunk 1 of 1 extracted 9 Ent + 8 Rel
# INFO: Extracting stage 165/179: astro_physics_1.pdf
# INFO: Processing d-id: astro_physics_1.pdf_11
# INFO:  == LLM cache == saving default: 59bf58b7aa1a836d72d98a1d39a29dab
# INFO: Merge N: Leader | 1+4
# INFO: Merge N: Follower | 1+2
# INFO: Merge N: C0 | 1+4
# INFO: Merge N: C1 | 1+4
# INFO: Merge E: Bayesian Stackelberg Game - Utility Matrices | 1+2
# INFO: Merge E: Follower - Leader | 1+4
# INFO: Merge E: C0 - C1 | 1+1
# INFO: Updating 8 entities  162/179: CSE_1.pdf
# INFO: Updating 5 relations 162/179: CSE_1.pdf
# INFO: Merging stage 163/179: CSE_1.pdf
# INFO: Merge N: θ | 1+2
# INFO: Merge N: t | 1+2
# INFO: Merge N: zt,θ | 1+1
# INFO: Merge N: wt,θ | 1+2
# INFO: Merge N: yθ | 1+2
# INFO: Updating 9 entities  163/179: CSE_1.pdf
# INFO: Writing graph with 1072 nodes, 1194 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 162/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 4d38d5c4f7de00d02c12d0b9727ded1e
# INFO: Updating 8 relations 163/179: CSE_1.pdf
# INFO: Writing graph with 1072 nodes, 1194 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 163/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 0d7dc50f53ea3e4ad09c3c6bd3d4ac25
# INFO: Chunk 1 of 1 extracted 10 Ent + 10 Rel
# INFO: Merging stage 164/179: astro_physics_1.pdf
# INFO: Merge N: DESI | 1+2
# INFO: Merge N: Baryon Acoustic Oscillations | 1+1
# INFO: Updating 10 entities  164/179: astro_physics_1.pdf
# INFO: Extracting stage 166/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_23
# INFO: Updating 10 relations 164/179: astro_physics_1.pdf
# INFO:  == LLM cache == saving default: 71c4cfd3d3e2402101038fd6a2b9a80b
# INFO: Chunk 1 of 1 extracted 9 Ent + 8 Rel
# INFO: Extracting stage 167/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_16
# INFO:  == LLM cache == saving default: 28c718c4d6bfcfb73e5d38a35e46b7be
# INFO: Merging stage 165/179: astro_physics_1.pdf
# INFO: Merge N: νCKN model | 1+1
# INFO: Merge N: DESI BAO+Hubble+DESY5 DR1 | 1+1
# INFO: Merge N: DESI BAO+Hubble+DESY5 DR2 | 1+1
# INFO: Merge N: Correlations | 1+1
# INFO: Merge N: ν | 1+2
# INFO: Merge N: Ω0 | 1+2
# INFO: Merge N: M | 1+4
# INFO: Merge N: H0 | 1+4
# INFO: Merge N: rd | 1+2
# INFO: Merge E: ν - Ω0 | 1+1
# INFO: Merge E: H0 - M | 1+1
# INFO: Merge E: H0 - rd | 1+1
# INFO: Updating 9 entities  165/179: astro_physics_1.pdf
# INFO: Writing graph with 1080 nodes, 1209 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 164/179: astro_physics_1.pdf
# INFO: Updating 8 relations 165/179: astro_physics_1.pdf
# INFO: Writing graph with 1080 nodes, 1209 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 165/179: astro_physics_1.pdf
# INFO:  == LLM cache == saving default: e3002dd9a7376b9ece1149ff6a6f8ceb
# INFO: Chunk 1 of 1 extracted 6 Ent + 4 Rel
# INFO: Merging stage 166/179: CSE_1.pdf
# INFO: Merge N: Bayesian Stackelberg Game | 1+4
# INFO: Merge N: No Learning Theorem | 1+1
# INFO: Merge N: Effective Learning | 1+2
# INFO: LLM merge N: Leader | 1+5
# INFO: Extracting stage 168/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_159
# INFO:  == LLM cache == saving default: d1dc9ca89da101d2eee8563d536c3b67
# INFO:  == LLM cache == saving default: e3147d28c7b4c21c4231e63ff4f513bf
# INFO:  == LLM cache == saving default: a789fa12064f06f659c3e0f089f034c2
# INFO: Merge N: Follower | 1+3
# INFO: Merge N: Dynamic Pricing Problem | 1+4
# INFO: LLM merge E: Follower - Leader | 1+5
# INFO:  == LLM cache == saving default: ecc4fb01dd4451635bd44d740f263033
# INFO: Chunk 1 of 1 extracted 10 Ent + 11 Rel
# INFO: Extracting stage 169/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_53
# INFO:  == LLM cache == saving default: 07465a50d1c9509e817abd6492b988f6
# INFO: Updating 6 entities  166/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 4ad24cb96a38797d3fcd21043108082d
# INFO: Chunk 1 of 1 extracted 7 Ent + 6 Rel
# INFO: Extracting stage 170/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_54
# INFO: Updating 4 relations 166/179: CSE_1.pdf
# INFO: Merging stage 167/179: CSE_1.pdf
# INFO: Merge N: Michael Albert | 1+1
# INFO: Merge N: Quinlan Dawkins | 1+1
# INFO: Merge N: Minbiao Han | 1+3
# INFO: Merge N: Haifeng Xu | 1+4
# INFO: Merge N: Stackelberg Games | 1+1
# INFO: Merge N: Policy | 1+1
# INFO: Updating 10 entities  167/179: CSE_1.pdf
# INFO: Writing graph with 1084 nodes, 1223 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 166/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 36971699c2f471f035b2e90a32b1b0e7
# INFO: Updating 11 relations 167/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: a851f29308a8382199492a2c7e4669f1
# INFO: Merging stage 168/179: CSE_1.pdf
# INFO: Merge N: Program (2) | 1+1
# INFO: Merge N: MIP | 1+2
# INFO: Merge N: Decision Variables | 1+1
# INFO: Merge E: Decision Variables - Program (2) | 1+1
# INFO: Updating 7 entities  168/179: CSE_1.pdf
# INFO: Writing graph with 1088 nodes, 1228 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 167/179: CSE_1.pdf
# INFO: Updating 6 relations 168/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 76439da8f6f1d0eb7f5f6ba621df3e76
# INFO: Chunk 1 of 1 extracted 11 Ent + 9 Rel
# INFO: Extracting stage 171/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_33
# INFO: Merging stage 169/179: CSE_1.pdf
# INFO: LLM merge N: Bayesian Stackelberg Game | 1+5
# INFO: Writing graph with 1090 nodes, 1228 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 168/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 981ec32ae77dcca7db3636061e04a611
# INFO:  == LLM cache == saving default: 514a5a10b4ca490e1eb8e30d37a4ceb1
# INFO: Chunk 1 of 1 extracted 9 Ent + 7 Rel
# INFO: Extracting stage 172/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_44
# INFO:  == LLM cache == saving default: e03c8ccf79e4c0c84dfead94a2832821
# INFO: Merge N: Dynamic Policy | 1+4
# INFO: Merge N: Optimal Static Policy | 1+2
# INFO: Merge N: Leader Strategy | 1+2
# INFO: Merge N: Follower | 1+4
# INFO: Merge N: Second Round | 1+1
# INFO: Merge N: Dynamic Pricing Game | 1+4
# INFO: Merge N: No Learning Theorem | 1+2
# INFO: Merge N: Utility | 1+1
# INFO: Merge E: Dynamic Policy - Optimal Static Policy | 1+1
# INFO: Updating 11 entities  169/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 06cc5e0b99edddac5467279fafa3a835
# INFO: Updating 9 relations 169/179: CSE_1.pdf
# INFO: Merging stage 170/179: CSE_1.pdf
# INFO: Merge N: Bayesian Stackelberg Game | 1+1
# INFO: Merge N: Myerson Price | 1+3
# INFO: Merge N: No Learning Theorem | 1+3
# INFO: Merge N: Utility Matrices | 1+3
# INFO: Merge E: Bayesian Stackelberg Game - No Learning Theorem | 1+1
# INFO: Merge E: Bayesian Stackelberg Game - Utility Matrices | 1+3
# INFO: Updating 9 entities  170/179: CSE_1.pdf
# INFO: Writing graph with 1095 nodes, 1241 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 169/179: CSE_1.pdf
# INFO: Updating 7 relations 170/179: CSE_1.pdf
# INFO: Writing graph with 1095 nodes, 1241 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 170/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: d931a268ea128464bc7e3615a9c8dd5c
# INFO: Chunk 1 of 1 extracted 8 Ent + 7 Rel
# INFO: Merging stage 171/179: CSE_1.pdf
# INFO: Merge N: Mechanism Design | 1+1
# INFO: Merge N: Stackelberg Games | 1+2
# INFO: Merge N: Haghtalab et al. | 1+1
# INFO: Updating 8 entities  171/179: CSE_1.pdf
# INFO: Extracting stage 173/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_131
# INFO: Updating 7 relations 171/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: fae6e3ac3cc74d93a66cdec2bea34f1f
# INFO: Chunk 1 of 1 extracted 10 Ent + 9 Rel
# INFO: Extracting stage 174/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_175
# INFO: Merging stage 172/179: CSE_1.pdf
# INFO: Merge N: Dynamic Bayesian Stackelberg Game | 1+2
# INFO: Merge N: Leader | 1+1
# INFO: LLM merge N: Follower | 1+5
# INFO: Writing graph with 1102 nodes, 1248 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 171/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: c842c0dd088bb4891562831d9c1dff83
# INFO:  == LLM cache == saving default: 746ff859adb696719e1bec1515dc5802
# INFO: Merge N: Dynamic Mechanism Design | 1+3
# INFO: LLM merge N: Dynamic Pricing Problem | 1+5
# INFO:  == LLM cache == saving default: 710dd79553618cdd77b17f21ef1ea276
# INFO:  == LLM cache == saving default: 0da05e5e68910be0302463c3e0f76127
# INFO: Merge N: Stackelberg Security Games | 1+1
# INFO: Updating 10 entities  172/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: da052e115f653ae1085af6dc8383466e
# INFO: Chunk 1 of 1 extracted 11 Ent + 8 Rel
# INFO: Extracting stage 175/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_118
# INFO: Updating 9 relations 172/179: CSE_1.pdf
# INFO: Merging stage 173/179: CSE_1.pdf
# INFO: Merge N: Theorem 3 | 1+4
# INFO: Merge N: Corollary 6 | 1+1
# INFO: Merge N: B | 1+2
# INFO: Merge N: C | 1+2
# INFO: Merge N: Hn | 1+2
# INFO: Merge N: ϕ | 1+2
# INFO: Merge E: Equation 14 - Equation 15 | 2+0
# INFO: Updating 11 entities  173/179: CSE_1.pdf
# INFO: Writing graph with 1109 nodes, 1264 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 172/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 689e0cabb301f8cbad611bf7b5b9428c
# INFO: Chunk 1 of 1 extracted 12 Ent + 13 Rel
# INFO: Extracting stage 176/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_125
# INFO: Updating 7 relations 173/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: f6c845243356820814ccb1ca58e4cd58
# INFO: Merging stage 174/179: CSE_1.pdf
# INFO: Merge N: Stackelberg Security Game | 1+2
# INFO: LLM merge N: C0 | 1+5
# INFO: Writing graph with 1109 nodes, 1264 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 173/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 3b2e370993b14a792b913847acad1715
# INFO: LLM merge N: C1 | 1+5
# INFO:  == LLM cache == saving default: e78f5ac7dbb68b84f77c56efdcd6209b
# INFO:  == LLM cache == saving default: 707fc54eab5425206cecca396949cb53
# INFO: Merge N: C2 | 1+3
# INFO: Merge N: Utility Matrices | 1+4
# INFO: Merge N: Leader | 1+2
# INFO: Merge N: Attacker | 1+2
# INFO: Updating 12 entities  174/179: CSE_1.pdf
# INFO: Updating 13 relations 174/179: CSE_1.pdf
# INFO: Writing graph with 1114 nodes, 1277 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 174/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 21a3351458ba47eac26cebee0294ce66
# INFO: Chunk 1 of 1 extracted 10 Ent + 9 Rel
# INFO: Merging stage 175/179: CSE_1.pdf
# INFO: Merge N: incentive compatibility | 1+1
# INFO: Updating 10 entities  175/179: CSE_1.pdf
# INFO: Extracting stage 177/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_166
# INFO:  == LLM cache == saving default: 578caa9a77f1646d43ecf9d023ddbe85
# INFO: Chunk 1 of 1 extracted 13 Ent + 10 Rel
# INFO: Extracting stage 178/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_119
# INFO: Updating 9 relations 175/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: c6da8839d38420b38d3dbb8d6c61d1b1
# INFO: Merging stage 176/179: CSE_1.pdf
# INFO: Merge N: Sm−1 | 1+1
# INFO: Merge N: G(m, k) | 1+2
# INFO: Merge N: ϕ∗ | 1+1
# INFO: Merge N: G(m, m−j) | 1+1
# INFO: Merge N: K | 1+2
# INFO: Merge N: νm−j | 1+1
# INFO: Merge E: G(m, m−j) - νm−j | 1+1
# INFO: Updating 13 entities  176/179: CSE_1.pdf
# INFO: Writing graph with 1130 nodes, 1295 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 175/179: CSE_1.pdf
# INFO: Updating 10 relations 176/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 71a9b81ef8d654c1b6766096dc99c6c6
# INFO: Writing graph with 1130 nodes, 1295 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 176/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: c058e309a1ee9f1773de24a91c9a7beb
# INFO: Chunk 1 of 1 extracted 7 Ent + 5 Rel
# INFO: Merging stage 177/179: CSE_1.pdf
# INFO: Merge N: MILP | 1+4
# INFO: Merge N: MIP | 1+3
# INFO: Merge N: Constraints | 1+1
# INFO: Merge N: DSE | 1+1
# INFO: Merge N: Theorem | 1+1
# INFO: Merge E: MILP - MIP | 1+2
# INFO: Updating 7 entities  177/179: CSE_1.pdf
# INFO: Extracting stage 179/179: CSE_1.pdf
# INFO: Processing d-id: CSE_1.pdf_124
# INFO: Updating 5 relations 177/179: CSE_1.pdf
# INFO: Writing graph with 1132 nodes, 1299 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 177/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: e73ee439c25974fea66b115e26e21ccf
# INFO: Chunk 1 of 1 extracted 13 Ent + 9 Rel
# INFO: Merging stage 178/179: CSE_1.pdf
# INFO: LLM merge N: Buyer | 1+5
# INFO:  == LLM cache == saving default: 1debea9581139d307615fa79e9feeb79
# INFO:  == LLM cache == saving default: 061d81205b32218c6833d0f7efba64d2
# INFO: LLM merge N: Seller | 1+5
# INFO:  == LLM cache == saving default: abc6dbe84e4aa19b44b76772fcabae0c
# INFO: Merge N: Utility | 1+2
# INFO: Merge N: v | 1+1
# INFO: Merge N: incentive compatibility | 1+2
# INFO: Updating 13 entities  178/179: CSE_1.pdf
# INFO: Updating 9 relations 178/179: CSE_1.pdf
# INFO: Writing graph with 1140 nodes, 1308 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 178/179: CSE_1.pdf
# INFO:  == LLM cache == saving default: 9e6c9871b9fe8d2736e66fe8c97cb78c
# INFO: Chunk 1 of 1 extracted 10 Ent + 8 Rel
# INFO: Merging stage 179/179: CSE_1.pdf
# INFO: Merge N: Hug and Schneider | 1+4
# INFO: Merge N: Corollary 1 | 1+4
# INFO: Merge N: Corollary 5 | 1+1
# INFO: LLM merge N: Theorem 3 | 1+5
# INFO:  == LLM cache == saving default: 823d1466a6e50706176f0d6731fad111
# INFO: Merge N: V θ(x∗, j∗θ(x∗)) | 1+1
# INFO: Merge E: Corollary 1 - Theorem 3 | 1+1
# INFO: Updating 10 entities  179/179: CSE_1.pdf
# INFO: Updating 8 relations 179/179: CSE_1.pdf
# INFO: Writing graph with 1145 nodes, 1315 edges
# INFO: In memory DB persist to disk
# INFO: Completed processing file 179/179: CSE_1.pdf
# INFO: Document processing pipeline completed

# %%
query = "Tell me about Learning in Dynamic Bayesian Stackelberg Games"
print(
  rag.query(
    query,
    param=QueryParam(mode="hybrid")
  )
)
# Out:
# INFO:  == LLM cache == saving hybrid: 5364db14231309f88fb8bb595e80e0dc
# INFO: Process 3612 building query context...
# INFO: Query nodes: Bayesian strategies, Stackelberg competition, Player types, Information structure, Decision-making, top_k: 60, cosine: 0.2
# INFO: Local query uses 54 entites, 141 relations, 17 chunks
# INFO: Query edges: Learning, Dynamic Bayesian Stackelberg Games, Game theory, top_k: 60, cosine: 0.2
# INFO: Global query uses 25 entites, 60 relations, 19 chunks
# INFO:  == LLM cache == saving hybrid: 487b7c6a7b960db376a201d26d7d753d
# ### Learning in Dynamic Bayesian Stackelberg Games
#
# Dynamic Bayesian Stackelberg Games are characterized by repeated interactions between a leader and a follower, where the follower's type is uncertain, modeled as a random variable known only to the follower. The leader, who commits to a strategy first, can only maintain a prior distribution on the follower's type (denoted as µ), which influences the leader's decision-making process.
#
# **Effective Learning Process**
#
# Effective learning in this context occurs when the leader can adapt their strategies based on the observed behaviors of the follower. A critical component of this learning process is Assumption 1, which ensures the existence of a learnable subgroup among the follower types, thereby facilitating effective strategy adaptation by the leader. This learning is driven by the distinct best responses exhibited by the follower types, allowing the leader to tailor their policies accordingly.
#
# **Contrast to No Learning Theorem**
#
# The No Learning Theorem indicates limitations in learning effectiveness under certain conditions, particularly within static settings. However, research highlights that learning can indeed be effective in dynamic scenarios, in contrast to the static policy outcomes suggested by the Theorem. For instance, algorithms developed for computing effective dynamic policies have shown significant enhancements in leader utility compared to static strategies.
#
# **Computational Frameworks**
#
# The dynamics of learning within these games can be effectively modeled using various approaches, including the dynamic Stackelberg equilibrium (DSE). The DSE allows for adaptation and communication of strategies over time, where the leader's commitment to flexible strategies ensures optimal outcomes in response to the follower's actions. The development of mixed-integer linear programming (MILP) formulations aids in computing these optimal policies, balancing complexity with actionable insights.
#
# Moreover, the presence of diverse follower types enhances the probability of successful learning, reinforcing the concept that varied strategic interactions lead to better decision-making outcomes for leaders.
#
# ### Conclusion
#
# In summary, learning in Dynamic Bayesian Stackelberg Games is a complex yet vital process that hinges on the effective adaptation of strategies based on observed follower behavior. By utilizing assumptions and mathematical frameworks, leaders can optimize their decision-making over time, demonstrating that effective learning is achievable in dynamic settings.
#
# ### References
# 1. Dynamic Bayesian Stackelberg Game - [KG] CSE_1.pdf
# 2. Assumption 1 (Existence of Learnable Sub-group) - [KG] CSE_1.pdf
# 3. No Learning Theorem - [KG] CSE_1.pdf
# 4. Mixed Integer Linear Program to compute the optimal dynamic policy - [DC] CSE_1.pdf
# 5. Dynamic Stackelberg Equilibrium - [KG] CSE_1.pdf

# %%
await rag.finalize_storages()

# %% [markdown]
# # LightRAG with Agno

# %%
# rag_tool.py

from agno.tools import tool

# @tool(
#     name="rag_query_tool",
#     description="Answer arbitrary queries using RAG in hybrid mode",
#     show_result=True
# )
def rag_query_tool(query: str) -> str:
    """
    Takes a user’s query and returns the RAG-generated answer using hybrid search.
    """
    # 👇 Replace this import with the real location of your 'rag' and 'QueryParam'

    return rag.query(
        query,
        param=QueryParam(mode="hybrid")
    )

# %%
# Define Pydantic model for structured output
class AnswerOutput(BaseModel):
    query: str = Field(..., description="The user's original query.")
    answer: str = Field(..., description="The answer to the user's query.")
    type: str = Field(..., description="Source of the answer: 'Knowledge/RAG' or 'Web Search'.")
    sources: List[str] = Field(..., description="List of sources used (URLs or document names).")

# %%
from agno.agent import RunResponse
from rich.pretty import pprint
from datetime import datetime

start_time = datetime.now()
print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

# Test the agent
# response: RunResponse = agent.run("ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখা সম্পর্কে আমাকে বলুন")
response: RunResponse = agent.run("Tell me about Learning in Dynamic Bayesian Stackelberg Games")

end_time = datetime.now()
elapsed = end_time - start_time

print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Elapsed Time: {elapsed.total_seconds():.2f} seconds")  # <-- FIXED
# Out:
# Start Time: 2025-06-08 16:57:58
# End Time: 2025-06-08 16:58:06
# Elapsed Time: 7.58 seconds

# %%
print(response.content)
# Out:
# query='Learning in Dynamic Bayesian Stackelberg Games' answer="Dynamic Bayesian Stackelberg Games (DBSGs) represent a strategic decision-making framework where a leader and follower interact under uncertainty regarding the follower’s type. The leader must make decisions based on incomplete information about the follower's payoff matrix, capturing the essence of strategic interactions where learning can be crucial for optimizing outcomes.\n\n### Effective Learning\n\nIn DBSGs, effective learning occurs when a leader can optimize their utility over multiple rounds based on the behavior of the follower. The primary goal for the leader is not merely identifying the follower's type but maximizing returns over interactions. This involves leveraging revealed preferences of the follower to distinguish types, allowing the leader to adapt and enhance strategies accordingly. The Dynamic Bayesian Stackelberg Equilibrium (DSE) encapsulates this optimal dynamic policy that combines learning with utility optimization.\n\nA significant aspect of effective learning is characterized by Assumption 1, which states that there exists a learnable subgroup among follower types. This condition allows leaders to differentiate between types based on distinct best responses, enhancing their strategic choices. Without this differentiation, learning is less effective, as illustrated by various examples where leaders fail to increase their utility systematically compared to static policies.\n\n### No Learning Theorem\n\nThe No Learning Theorem illustrates conditions under which learning is ineffective, particularly in static situations. In cases where the leader cannot utilize historical responses from the follower, the utility remains constrained, limiting adaptability. However, findings show that when interaction is frequent and strategic, as in DBSGs, learning is generally effective, challenging the assumptions laid out by the No Learning Theorem.\n\n### Practical Applications\n\nDBSGs have substantial practical implications, especially in dynamic pricing and resource allocation scenarios. In these settings, the leader's ability to adjust strategies based on follower observations can lead to more favorable outcomes compared to static approaches. Moreover, experimental analyses have indicated that the DSE can achieve comparable utility to optimal static policies in various settings, especially when designed to facilitate learning over time.\n\n### Conclusion\n\nDynamic Bayesian Stackelberg Games highlight the intricate balance between strategy adaptation and effective learning in uncertain environments. The frameworks established by DBSGs demonstrate that learning can substantially enhance decision-making when appropriately modeled, providing valuable insights for various strategic applications." type='Knowledge/RAG' sources=['CSE_1.pdf']

# %%
from agno.agent import RunResponse
from rich.pretty import pprint
from datetime import datetime

start_time = datetime.now()
print(f"Start Time: {start_time.strftime('%Y-%m-%d %H:%M:%S')}")

# Test the agent
response: RunResponse = agent.run("ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখা সম্পর্কে আমাকে বলুন")
# response: RunResponse = agent.run("Tell me about Learning in Dynamic Bayesian Stackelberg Games")

end_time = datetime.now()
elapsed = end_time - start_time

print(f"End Time: {end_time.strftime('%Y-%m-%d %H:%M:%S')}")
print(f"Elapsed Time: {elapsed.total_seconds():.2f} seconds")  # <-- FIXED
# Out:
# Start Time: 2025-06-08 16:59:17
# INFO:  == LLM cache == saving hybrid: 9f1c20b915487f4819082e20206e8f82
# INFO: Process 3612 building query context...
# INFO: Query nodes: গেম থিওরি, অর্থনৈতিক সিদ্ধান্ত, নীতিনির্ধারণ, অন্তর্ভুক্তি, সামাজিক আচরণ, top_k: 60, cosine: 0.2
# INFO: Local query uses 27 entites, 76 relations, 13 chunks
# INFO: Query edges: ডায়নামিক বেয়েসিয়ান, স্ট্যাকেলবার্গ গেম, শেখা, top_k: 60, cosine: 0.2
# INFO: Global query uses 29 entites, 60 relations, 19 chunks
# INFO:  == LLM cache == saving hybrid: 0113e4b459c26d1aed37a84b5246c37e
# End Time: 2025-06-08 16:59:52
# Elapsed Time: 35.13 seconds

# %%
print(response.content)
# Out:
# query='ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখা সম্পর্কে আমাকে বলুন' answer='ডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখার প্রক্রিয়া এমন একটি খেলার প্রেক্ষাপট তৈরি করে যেখানে নেতা এবং অনুসারী উভয়েরই অপর্যাপ্ত তথ্য থাকে। এই গেমে, নেতা তার কৌশলগুলি সেট করে যেমন, নেতৃত্ব দেওয়ার সময়, অনুসারী সেই কৌশলগুলির প্রতিক্রিয়া দেয়। শেখার এই প্রক্রিয়াটি বিশেষভাবে গুরুত্বপূর্ণ কারণ এটি নেতা তাদের কৌশলগুলোকে নিখুঁত করতে এবং তাদের উপকারিতা বাড়াতে সহায়তা করে।\n\n**শেখার কার্যকরী প্রক্রিয়া**: \nডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমে শেখা কার্যকরীভাবে ঘটে যখন নেতা কথোপকথনের পরিবর্তে তথ্য অধিগ্রহণের মাধ্যমে প্রত্যাশিত ফলাফলগুলিকে সংশোধন করে। গবেষণা দেখায় যে নেতা কৌশলগত প্রতিপক্ষের বিরুদ্ধে পুনরাবৃত্ত খেলার মধ্যে মাধ্যমে তার লাভ বাড়ানোর জন্য তথ্য অর্জন করতে পারে, এবং এটি শুধুমাত্র যোগাযোগের বিকল্প হিসাবে কাজ করে না। এই শেখার মাধ্যমে কিভাবে অনুসারী প্রকারভেদগুলি সনাক্ত করা যায় এবং সেগুলির সাথে কিভাবে প্রতিক্রিয়াশীল হতে হবে, তা শেখা যায়।\n\n**মিশ্র সংখ্যা লিনিয়ার প্রোগ্রাম (MILP)**: \nডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখার ফ্রেমওয়ার্কের জন্য একটি কার্যকরী অ্যালগরিদম বিকাশ করা হয়েছে। গেমের জন্য MILP  তৈরি করা হয়েছে যা ফলদায়ক কৌশলগুলো গণনা করতে সহায়তা করে, যদিও এটি বিস্তৃত হতে পারে। গেমের গঠন স্কেলেবিলিটির ক্ষেত্রে কার্যকরভাবে কাজ করে, যদিও এটি এখনও কিছু সীমাবদ্ধতা রয়েছে।\n\n**কৌশলগত ভিন্নতা এবং শেখার কার্যকরীতা**: \nগবেষণা থেকে বোঝা যাচ্ছে যে, যদি খেলায় প্রবেশ করা অনুসারীর প্রকারভেদগুলি সত্যিই বিভিন্ন হয়, তাহলে শেখা সম্ভবনাটা বাড়ছে। বিশেষ করে গেমের ধারণা ও ফলস্বরূপ প্রচলিত ধারণা, "নো লার্নিং থিওরেম" সাধারণভাবে প্রযোজ্য হবে না।\n\n### উপসংহার\nডায়নামিক বেয়েসিয়ান স্ট্যাকেলবার্গ গেমসে শেখার প্রক্রিয়া নেতাদের জন্য তাদের কৌশলগুলি উন্নত করার একটি কার্যকরী মাধ্যম। খেলোয়াড়দের তথ্য গ্রহণের মাধ্যমে তার কৌশলগুলি শোধন করার ক্ষমতা এবং তথাকথিত "নো লার্নিং থিওরেম" এর উপাদানগুলির দিকে নজর দেওয়া বিতর্কিত করে তোলে।' type='Knowledge/RAG' sources=['Dynamic Bayesian Stackelberg Games - Knowledge Base [KG] CSE_1.pdf', 'Effective Learning in Dynamic Bayesian Stackelberg Games - Document Chunk [DC] CSE_1.pdf', 'Learning in Dynamic Bayesian Stackelberg Games Development - Document Chunk [DC] CSE_1.pdf', 'Mixed Integer Linear Program for Dynamic Bayesian Games - Document Chunk [DC] CSE_1.pdf', 'No Learning Theorem in Dynamic Pricing - Document Chunk [DC] CSE_1.pdf']
